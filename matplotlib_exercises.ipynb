# %%
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
import math
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Q1
# Use matplotlib to plot the following equation:
# $$x^2 - x + 2$$
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = list(range(-100,101))
y = [x*x - x + 2 for x in x]
plt.plot(x, y)
plt.annotate('Origin',xy=(0,3), xytext=(0,5000),arrowprops=dict(facecolor='blue'))
# Out:
# Text(0, 5000, 'Origin')

# %% [markdown]
# # Q2
# ## Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#  $$y = \sqrt{x}$$

# %%
x1 = [x /10 for x in range(0,100)]
y1 = [math.sqrt(x) for x in x1]
plt.plot(x1,y1)
plt.title('$y = \sqrt{x}$')
plt.xlabel('X',loc='center')
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# $$y = x^3$$

# %%
x2 = [x/10 for x in range(-100,101)]
y2 = [x ** 3 for x in x2]
plt.plot(x2,y2)
plt.xlabel('X')
plt.ylabel('Y',rotation=0)
plt.title('$x^3$',loc='center')
# Out:
# Text(0.5, 1.0, '$x^3$')

# %% [markdown]
# $$y = 2^x$$

# %%
x3 = list(range(-100,101))
x3 = [x/10 for x in x3]
y3 = [2 ** x for x in x3]
plt.plot(x3,y3)

# %% [markdown]
# $$y = {1 \over{x+1}}$$

# %%
x4 = list(range(-200,1))
x4 = [x / 10 for x in x]
y4 = [math.inf if x == -1 else 1/(x+1) for x in x4]

        
plt.plot(x4,y4)

# %% [markdown]
# # Q3
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(10,10))
plt.suptitle('Mathy Math Math!')
plt.subplot(221)
plt.plot(x1,y1)
plt.title('$\sqrt{x}$')
plt.subplot(222)
plt.plot(x2,y2)
plt.title('$x^3$')
plt.subplot(223)
plt.plot(x3,y3)
plt.title('$2^X$')
plt.subplot(224)
plt.plot(x4,y4)
plt.title('$1/(1 + x)$')
# Out:
# Text(0.5, 1.0, '$1/(1 + x)$')

# %% [markdown]
# # Q4
# Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(10,10))
plt.suptitle('Lotsa Spamathy')
plt.plot(x1,y1,label='$\sqrt{x}$',marker='$\sqrt{x}$')
plt.plot(x2,y2, label='$x^3$',marker='$x^3$')
plt.plot(x3,y3, label='$2^x$',marker='$2^x$')
plt.plot(x4,y4,label='1/(1+x)',marker='$1/(1+x)$')
plt.legend(loc='upper left')
plt.xlim(-10,10)
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)
